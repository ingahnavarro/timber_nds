# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import timber_nds.settings as settings
import timber_nds.calculation as calculation
import timber_nds.design as design

# %% [markdown]
# ## Parameters

# %% [markdown]
# **Material Properties:**
#
# * `species`: Wood species.
# * `specific_gravity`: Specific gravity of the wood.
# * `fibre_saturation_point`: Fiber saturation point of the wood (%).
# * `moisture_content`: Moisture content of the wood (%).
# * `e_modulus`: Modulus of elasticity of the wood (kgf/cm2).
# * `fb`: Bending strength (kgf/cm2).
# * `ft`: Tensile strength (kgf/cm2).
# * `fv`: Shear strength (kgf/cm2).
# * `fc`: Compression strength parallel to the grain (kgf/cm2).
# * `fc_perp`: Compression strength perpendicular to the grain (kgf/cm2).

# %%
species = "Douglas Fir-Larch"
specific_gravity = 0.55
fibre_saturation_point = 28
moisture_content = 19 #19%
e_modulus = 115000 # kgf/cm2
fb = 280  # kgf/cm2
ft = 280  # kgf/cm2
fv = 45  # kgf/cm2
fc = 280  # kgf/cm2
fc_perp = 28  # kgf/cm2

# %%
wood_material = settings.WoodMaterial(
    name=species,
    specific_gravity=specific_gravity,
    fibre_saturation_point=fibre_saturation_point,
    tension_strength=ft,
    bending_strength=fb,
    shear_strength=fv,
    compression_perpendicular_strength=fc_perp,
    compression_parallel_strength=fc,
    elastic_modulus=e_modulus,
    color="Brown"
)

# %% [markdown]
# **Geometric Dimensions:**
#
# * `width`: Width of the cross-section (cm).
# * `depth`: Depth of the cross-section (cm).
# * `length`: Length of the element (cm).
# * `k_factor`: Effective length factor.

# %%
# Geometry
width = 5. # cm
depth = 15. # cm
length = 400 # cm
k_factor = 1.0

# Geometry
width_2 = 100. # cm
depth_2 = 150. # cm
length_2 = 200 # cm
k_factor_2 = 2.0

# Geometry
width_3 = 15. # cm
depth_3 = 15. # cm
length_3 = 200 # cm
k_factor_3 = 2.0

# %%
section = settings.RectangularSection("sección 1", depth=depth, width=width)
section_2 = settings.RectangularSection("sección 2", depth=depth_2, width=width_2)
section_3 = settings.RectangularSection("sección 3", depth=depth_3, width=width_3)
list_sections = [section, section_2, section_3]
list_sections
# Out:
# [RectangularSection(name='sección 1', depth=15.0, width=5.0),
#  RectangularSection(name='sección 2', depth=150.0, width=100.0),
#  RectangularSection(name='sección 3', depth=15.0, width=15.0)]

# %%
element = settings.MemberDefinition("elemento 1", length=length, )
element_2 = settings.MemberDefinition("elemento 2", length=length_2, )
element_3 = settings.MemberDefinition("elemento 3", length=length_3, )
list_members = [element, element_2, element_3]

# %% [markdown]
# **All Adjustment Factors:**
#
# * Several adjustment factors are defined for tension  `TensionAdjustmentFactors`, bending `BendingAdjustmentFactors`, shear `ShearAdjustmentFactors`, compression `CompressionAdjustmentFactors`, compression perpendicular to the grain `PerpendicularAdjustmentFactors`, and modulus of elasticity `ElasticModulusAdjustmentFactors`.

# %% [markdown]
# **Strength Reduction Factors:**
#
# * `phi_tension`: Strength reduction factor for tension.
# * `phi_bending`: Strength reduction factor for bending.
# * `phi_shear`: Strength reduction factor for shear.
# * `phi_compression`: Strength reduction factor for compression.
# * `phi_perp_compression`: Strength reduction factor for compression perpendicular to the grain.

# %%
phi_tension = 0.90
phi_bending = 0.85
phi_shear = 0.75
phi_compression = 0.90
phi_perp_compression = 0.65

# %% [markdown]
# **Adjustment Factors:**
#
# * `TensionAdjustmentFactors`: Factors to adjust the basic tensile stress.
# * `BendingAdjustmentFactors`: Factors to adjust the basic bending stress.
# * `ShearAdjustmentFactors`: Factors to adjust the basic shear stress.
# * `CompressionAdjustmentFactors`: Factors to adjust the basic compression stress parallel to the grain.
# * `PerpendicularAdjustmentFactors`: Factors to adjust the basic compression stress perpendicular to the grain.
# * `ElasticModulusAdjustmentFactors`: Factors to adjust the modulus of elasticity.

# %%
ft_factors = settings.TensionAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.85,
    due_temperature=1.0,
    due_size=1.0,
    due_incising=1.0,
    due_format_conversion=2.70,
    due_resistance_reduction=0.80
)

# %%
fb_factors_yy = settings.BendingAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.85,
    due_temperature=1.0, 
    due_size=1.0,
    due_beam_stability=1.0,
    due_flat_use=1.0,
    due_incising=1.0,
    due_repetitive_member=1.0,
    due_format_conversion=2.54,
    due_resistance_reduction=0.85
)

# %%
fb_factors_zz = settings.BendingAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.85,
    due_temperature=1.0,
    due_size=1.0,
    due_beam_stability=1.0,
    due_flat_use=1.0,
    due_incising=1.0,
    due_repetitive_member=1.0,
    due_format_conversion=2.54,
    due_resistance_reduction=0.85
)

# %%
fv_factors = settings.ShearAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.97,
    due_temperature=1.0,
    due_incising=1.0,
    due_format_conversion=2.88,
    due_resistance_reduction=0.75
)

# %%
fc_factors_yy = settings.CompressionAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.80,
    due_temperature=1.0,
    due_size=1.0,
    due_incising=1.0,
    due_column_stability=1.0,
    due_format_conversion=2.40,
    due_resistance_reduction=0.90
)

# %%
fc_factors_zz = settings.CompressionAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.80,
    due_temperature=1.0,
    due_size=1.0,
    due_incising=1.0,
    due_column_stability=1.0,
    due_format_conversion=2.40,
    due_resistance_reduction=0.90
)

# %%
fc_perp_factors = settings.PerpendicularAdjustmentFactors(
    due_time_effect=1.0,
    due_moisture=0.67,
    due_temperature=1.0,
    due_bearing_area=1.0,
    due_format_conversion=1.67,
    due_resistance_reduction=0.90
)

# %%
e_factors = settings.ElasticModulusAdjustmentFactors(
    due_moisture=0.90,
    due_temperature=1.0,
    due_incising=1.0,
    due_format_conversion=1.76,
    due_resistance_reduction=0.85
)

# %% [markdown]
# ## Forces

# %%
force = settings.Forces(
    name="force_1",
    axial=10000,
    shear_y= 10.0,
    shear_z= 10.0,
    moment_xx = 0.0,
    moment_yy = 0.0,
    moment_zz = 0.0
)

force_2 = settings.Forces(
    name="force_2",
    axial=20000,
    shear_y= 00.0,
    shear_z= 00.0,
    moment_xx = 30.0,
    moment_yy = 400.0,
    moment_zz = 50.0
)
force_3 = settings.Forces(
    name="force_3",
    axial=-10000,
    shear_y= 10.0,
    shear_z= 0.0,
    moment_xx = 0.0,
    moment_yy = 1000.,
    moment_zz = 0.0
)

force_4 = settings.Forces(
    name="force_4",
    axial=-20000,
    shear_y= 10.0,
    shear_z= 20.0,
    moment_xx = 30.0,
    moment_yy = 400.0,
    moment_zz = 50.0
)
list_forces = [force, force_2, force_3, force_4]

# %% [markdown]
# ## Calculate for all forces

# %%
forces_results = design.check_for_all_forces(
    section, element, list_forces, wood_material, ft_factors,
    fb_factors_yy, fb_factors_zz,
    fv_factors,
    fc_factors_yy, fc_factors_zz, fc_perp_factors,
    e_factors
    )
# Out:
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 1939.34it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4

# %% [markdown]
# ## Calculate for all forces for each section

# %%
sections_results = design.check_for_all_sections(
    list_sections, element, list_forces, wood_material, ft_factors,
    fb_factors_yy, fb_factors_zz,
    fv_factors,
    fc_factors_yy, fc_factors_zz, fc_perp_factors,
    e_factors
    )
# Out:
# Checking for all sections:   0%|          | 0/3 [00:00<?, ?it/s]
# ..................................................
# Calculando para la sección: sección 1
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3698.68it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 2
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 1824.01it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 3
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3892.63it/s]
# Checking for all sections: 100%|██████████| 3/3 [00:00<00:00, 223.66it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4

# %% [markdown]
# ## Calculate for all forces for each section for every element

# %%
elements_results = design.check_for_all_elements(
    list_sections, list_members, list_forces, wood_material, ft_factors,
    fb_factors_yy, fb_factors_zz,
    fv_factors,
    fc_factors_yy, fc_factors_zz, fc_perp_factors,
    e_factors
    )
# Out:
# Checking for all sections:   0%|          | 0/3 [00:00<?, ?it/s]
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# Calculando para el elemento: elemento 1
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# cking for all sections:   0%|          | 0/3 [00:00<?, ?it/s]
# ..................................................
# Calculando para la sección: sección 1
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3515.76it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 2
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3208.49it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 3
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3397.57it/s]
# Checking for all sections: 100%|██████████| 3/3 [00:00<00:00, 265.70it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# Calculando para el elemento: elemento 2
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# cking for all sections:   0%|          | 0/3 [00:00<?, ?it/s]
# ..................................................
# Calculando para la sección: sección 1
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 1694.50it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 2
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3499.63it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 3
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 1871.41it/s]
# Checking for all sections: 100%|██████████| 3/3 [00:00<00:00, 270.73it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# Calculando para el elemento: elemento 3
# ::::::::::::::::::::::::::::::::::::::::::::::::::
# cking for all sections:   0%|          | 0/3 [00:00<?, ?it/s]
# ..................................................
# Calculando para la sección: sección 1
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<00:00, 3258.34it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 2
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4
# ..................................................
# Calculando para la sección: sección 3
# ..................................................
# Checking for all forces: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Checking for all sections: 100%|██████████| 3/3 [00:00<00:00, 257.96it/s]
# Checking for all sections: 100%|██████████| 3/3 [00:00<00:00, 58.05it/s]
# Calculando para la fuerza: force_1
# Calculando para la fuerza: force_2
# Calculando para la fuerza: force_3
# Calculando para la fuerza: force_4

# %%
elements_results
# Out:
#         member    section    force   dcr_max  axial tension  tension (dcr)  \
# 0   elemento 1  sección 1  force_1  0.275573              0       0.000000
# 1   elemento 1  sección 1  force_2  0.551146              0       0.000000
# 2   elemento 1  sección 1  force_3  0.010379          10000       0.259363
# 3   elemento 1  sección 1  force_4  0.005709          20000       0.518726
# 4   elemento 1  sección 2  force_1  0.001378              0       0.000000
# 5   elemento 1  sección 2  force_2  0.002756              0       0.000000
# 6   elemento 1  sección 2  force_3  0.000011          10000       0.001297
# 7   elemento 1  sección 2  force_4  0.000021          20000       0.002594
# 8   elemento 1  sección 3  force_1  0.091858              0       0.000000
# 9   elemento 1  sección 3  force_2  0.183715              0       0.000000
# 10  elemento 1  sección 3  force_3  0.003460          10000       0.086454
# 11  elemento 1  sección 3  force_4  0.001557          20000       0.172909
# 12  elemento 2  sección 1  force_1  0.275573              0       0.000000
# 13  elemento 2  sección 1  force_2  0.551146              0       0.000000
# 14  elemento 2  sección 1  force_3  0.010379          10000       0.259363
# 15  elemento 2  sección 1  force_4  0.005709          20000       0.518726
# 16  elemento 2  sección 2  force_1  0.001378              0       0.000000
# 17  elemento 2  sección 2  force_2  0.002756              0       0.000000
# 18  elemento 2  sección 2  force_3  0.000011          10000       0.001297
# 19  elemento 2  sección 2  force_4  0.000021          20000       0.002594
# 20  elemento 2  sección 3  force_1  0.091858              0       0.000000
# 21  elemento 2  sección 3  force_2  0.183715              0       0.000000
# 22  elemento 2  sección 3  force_3  0.003460          10000       0.086454
# 23  elemento 2  sección 3  force_4  0.001557          20000       0.172909
# 24  elemento 3  sección 1  force_1  0.275573              0       0.000000
# 25  elemento 3  sección 1  force_2  0.551146              0       0.000000
# 26  elemento 3  sección 1  force_3  0.010379          10000       0.259363
# 27  elemento 3  sección 1  force_4  0.005709          20000       0.518726
# 28  elemento 3  sección 2  force_1  0.001378              0       0.000000
# 29  elemento 3  sección 2  force_2  0.002756              0       0.000000
# 30  elemento 3  sección 2  force_3  0.000011          10000       0.001297
# 31  elemento 3  sección 2  force_4  0.000021          20000       0.002594
# 32  elemento 3  sección 3  force_1  0.091858              0       0.000000
# 33  elemento 3  sección 3  force_2  0.183715              0       0.000000
# 34  elemento 3  sección 3  force_3  0.003460          10000       0.086454
# 35  elemento 3  sección 3  force_4  0.001557          20000       0.172909
#
#     axial compression  compression (dcr)  moment yy  moment zz  \
# 0               10000           0.275573        0.0        0.0
# 1               20000           0.551146      400.0       50.0
# 2                   0           0.000000     1000.0        0.0
# 3                   0           0.000000      400.0       50.0
# 4               10000           0.001378        0.0        0.0
# 5               20000           0.002756      400.0       50.0
# 6                   0           0.000000     1000.0        0.0
# 7                   0           0.000000      400.0       50.0
# 8               10000           0.091858        0.0        0.0
# 9               20000           0.183715      400.0       50.0
# 10                  0           0.000000     1000.0        0.0
# 11                  0           0.000000      400.0       50.0
# 12              10000           0.275573        0.0        0.0
# 13              20000           0.551146      400.0       50.0
# 14                  0           0.000000     1000.0        0.0
# 15                  0           0.000000      400.0       50.0
# 16              10000           0.001378        0.0        0.0
# 17              20000           0.002756      400.0       50.0
# 18                  0           0.000000     1000.0        0.0
# 19                  0           0.000000      400.0       50.0
# 20              10000           0.091858        0.0        0.0
# 21              20000           0.183715      400.0       50.0
# 22                  0           0.000000     1000.0        0.0
# 23                  0           0.000000      400.0       50.0
# 24              10000           0.275573        0.0        0.0
# 25              20000           0.551146      400.0       50.0
# 26                  0           0.000000     1000.0        0.0
# 27                  0           0.000000      400.0       50.0
# 28              10000           0.001378        0.0        0.0
# 29              20000           0.002756      400.0       50.0
# 30                  0           0.000000     1000.0        0.0
# 31                  0           0.000000      400.0       50.0
# 32              10000           0.091858        0.0        0.0
# 33              20000           0.183715      400.0       50.0
# 34                  0           0.000000     1000.0        0.0
# 35                  0           0.000000      400.0       50.0
#
#     biaxial bending (dcr)  shear y  shear z  shear y (dcr)  shear z (dcr)  \
# 0                0.000000     10.0     10.0       0.002121       0.002121
# 1                0.005709      0.0      0.0       0.000000       0.000000
# 2                0.010379     10.0      0.0       0.002121       0.000000
# 3                0.005709     10.0     20.0       0.002121       0.004243
# 4                0.000000     10.0     10.0       0.000011       0.000011
# 5                0.000002      0.0      0.0       0.000000       0.000000
# 6                0.000005     10.0      0.0       0.000011       0.000000
# 7                0.000002     10.0     20.0       0.000011       0.000021
# 8                0.000000     10.0     10.0       0.000707       0.000707
# 9                0.001557      0.0      0.0       0.000000       0.000000
# 10               0.003460     10.0      0.0       0.000707       0.000000
# 11               0.001557     10.0     20.0       0.000707       0.001414
# 12               0.000000     10.0     10.0       0.002121       0.002121
# 13               0.005709      0.0      0.0       0.000000       0.000000
# 14               0.010379     10.0      0.0       0.002121       0.000000
# 15               0.005709     10.0     20.0       0.002121       0.004243
# 16               0.000000     10.0     10.0       0.000011       0.000011
# 17               0.000002      0.0      0.0       0.000000       0.000000
# 18               0.000005     10.0      0.0       0.000011       0.000000
# 19               0.000002     10.0     20.0       0.000011       0.000021
# 20               0.000000     10.0     10.0       0.000707       0.000707
# 21               0.001557      0.0      0.0       0.000000       0.000000
# 22               0.003460     10.0      0.0       0.000707       0.000000
# 23               0.001557     10.0     20.0       0.000707       0.001414
# 24               0.000000     10.0     10.0       0.002121       0.002121
# 25               0.005709      0.0      0.0       0.000000       0.000000
# 26               0.010379     10.0      0.0       0.002121       0.000000
# 27               0.005709     10.0     20.0       0.002121       0.004243
# 28               0.000000     10.0     10.0       0.000011       0.000011
# 29               0.000002      0.0      0.0       0.000000       0.000000
# 30               0.000005     10.0      0.0       0.000011       0.000000
# 31               0.000002     10.0     20.0       0.000011       0.000021
# 32               0.000000     10.0     10.0       0.000707       0.000707
# 33               0.001557      0.0      0.0       0.000000       0.000000
# 34               0.003460     10.0      0.0       0.000707       0.000000
# 35               0.001557     10.0     20.0       0.000707       0.001414
#
#     bending and tension (dcr)  bending and compression (dcr)  \
# 0                    0.000000                       0.075941
# 1                    0.005709                       0.309471
# 2                    0.269742                       0.010379
# 3                    0.524435                       0.005709
# 4                    0.000000                       0.000002
# 5                    0.000002                       0.000010
# 6                    0.001302                       0.000005
# 7                    0.002596                       0.000002
# 8                    0.000000                       0.008438
# 9                    0.001557                       0.035308
# 10                   0.089914                       0.003460
# 11                   0.174466                       0.001557
# 12                   0.000000                       0.075941
# 13                   0.005709                       0.309471
# 14                   0.269742                       0.010379
# 15                   0.524435                       0.005709
# 16                   0.000000                       0.000002
# 17                   0.000002                       0.000010
# 18                   0.001302                       0.000005
# 19                   0.002596                       0.000002
# 20                   0.000000                       0.008438
# 21                   0.001557                       0.035308
# 22                   0.089914                       0.003460
# 23                   0.174466                       0.001557
# 24                   0.000000                       0.075941
# 25                   0.005709                       0.309471
# 26                   0.269742                       0.010379
# 27                   0.524435                       0.005709
# 28                   0.000000                       0.000002
# 29                   0.000002                       0.000010
# 30                   0.001302                       0.000005
# 31                   0.002596                       0.000002
# 32                   0.000000                       0.008438
# 33                   0.001557                       0.035308
# 34                   0.089914                       0.003460
# 35                   0.174466                       0.001557
#
#     compression perpendicular  compression perpendicular (dcr)
# 0                        10.0                         0.354657
# 1                         0.0                         0.000000
# 2                         0.0                         0.000000
# 3                        20.0                         0.709313
# 4                        10.0                         0.354657
# 5                         0.0                         0.000000
# 6                         0.0                         0.000000
# 7                        20.0                         0.709313
# 8                        10.0                         0.354657
# 9                         0.0                         0.000000
# 10                        0.0                         0.000000
# 11                       20.0                         0.709313
# 12                       10.0                         0.354657
# 13                        0.0                         0.000000
# 14                        0.0                         0.000000
# 15                       20.0                         0.709313
# 16                       10.0                         0.354657
# 17                        0.0                         0.000000
# 18                        0.0                         0.000000
# 19                       20.0                         0.709313
# 20                       10.0                         0.354657
# 21                        0.0                         0.000000
# 22                        0.0                         0.000000
# 23                       20.0                         0.709313
# 24                       10.0                         0.354657
# 25                        0.0                         0.000000
# 26                        0.0                         0.000000
# 27                       20.0                         0.709313
# 28                       10.0                         0.354657
# 29                        0.0                         0.000000
# 30                        0.0                         0.000000
# 31                       20.0                         0.709313
# 32                       10.0                         0.354657
# 33                        0.0                         0.000000
# 34                        0.0                         0.000000
# 35                       20.0                         0.709313

# %% [markdown]
# ## Filtering results

# %%
filtered_results = design.filter_and_export_results(
    results_df = elements_results,
    filters = {
        'section': ['sección 1', 'sección 3'],
        'dcr_max': {'range': {'min': 0.50, 'max': 1.50}},
    },
    sort_by="dcr_max",
    sort_order = "desc"
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 filtered_results = design.filter_and_export_results(
#       2     results_df = elements_results,
#       3     filters = {
#       4         'section': ['sección 1', 'sección 3'],
#       5         'dcr_max': {'range': {'min': 0.50, 'max': 1.50}},
#       6     },
#       7     sort_by="dcr_max",
#       8     sort_order = "desc"
#       9 )
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\timber_nds\design.py:713, in filter_and_export_results(results_df, filters, output_path, output_filename, sort_by, sort_order)
#     710 else:
#     711     output_path = os.path.join(output_path, output_filename)
# --> 713 filtered_df.to_excel(output_path, index=False)
#     714 print(f"Filtered results exported to: {output_path}")
#     715 return filtered_df
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:204, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     201 if mode == "a":
#     202     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 204 super().__init__(
#     205     path,
#     206     engine=engine,
#     207     date_format=date_format,
#     208     datetime_format=datetime_format,
#     209     mode=mode,
#     210     storage_options=storage_options,
#     211     if_sheet_exists=if_sheet_exists,
#     212     engine_kwargs=engine_kwargs,
#     213 )
#     215 try:
#     216     self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\miniforge3\envs\timber_design\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:\Users\ingah\miniforge3\envs\timber_design\Lib\tests\test_data'

# %%
# filtered_results = design.filter_and_export_results(
#     results_df = elements_results,
#     filters = {
#         'section': ['sección 1', 'sección 3'],
#         'dcr_max': {'range': {'min': 0.50, 'max': 1.50}},
#     },
#     output_path=write your path here
#     output_filename=write your filename.xlsx here
#     sort_by="dcr_max",
#     sort_order = "desc"
# )

# %%
filtered_results
